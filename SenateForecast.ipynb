# %%
elements="""<g transform="translate(190,70)"><text x="-185" y="5" class="top-label state-label" id="">Election</text><text x="740" y="5" class="top-label end chance-winning-label" id="">of winning</text><text x="740" y="-10" class="top-label end chance-winning-label" id="">leader's chance</text><text x="280" y="-35" class="top-label expected-margin middle" id="">expected margin of victory</text><text x="-118" y="-2" class="sort-triangle" id="revState-sort-triangle">▲</text><text x="-118" y="6" class="sort-triangle" id="state-sort-triangle">▼</text><text x="385" y="-42" class="sort-triangle" id="dem-sort-triangle">▲</text><text x="385" y="-34" class="sort-triangle" id="rep-sort-triangle">▼</text><text x="743" y="-2" class="sort-triangle" id="winProbDesc-sort-triangle">▲</text><text x="743" y="6" class="sort-triangle selected" id="winProbAsc-sort-triangle">▼</text><rect x="-190" y="-10" class="hover-box state-hover" width="90" height="20" opacity="0"></rect><rect x="170" y="-50" class="hover-box favored-party-hover" width="230" height="20" opacity="0"></rect><rect x="660" y="-25" class="hover-box chance-winning-hover" width="110" height="35" opacity="0"></rect><g><g class="axis"><g class="tick" transform="translate(560,0)" style="opacity: 1;"><line y2="-6" x2="0"></line><text y="-9" x="0" dy="0em" class="rep" style="text-anchor: middle;">+50</text></g><g class="tick" transform="translate(504,0)" style="opacity: 1;"><line y2="-6" x2="0"></line><text y="-9" x="0" dy="0em" class="rep" style="text-anchor: middle;">+40</text></g><g class="tick" transform="translate(448,0)" style="opacity: 1;"><line y2="-6" x2="0"></line><text y="-9" x="0" dy="0em" class="rep" style="text-anchor: middle;">+30</text></g><g class="tick" transform="translate(392.00000000000006,0)" style="opacity: 1;"><line y2="-6" x2="0"></line><text y="-9" x="0" dy="0em" class="rep" style="text-anchor: middle;">+20</text></g><g class="tick" transform="translate(336,0)" style="opacity: 1;"><line y2="-6" x2="0"></line><text y="-9" x="0" dy="0em" class="rep" style="text-anchor: middle;">+10</text></g><g class="tick" transform="translate(280,0)" style="opacity: 1;"><line y2="-6" x2="0"></line><text y="-9" x="0" dy="0em" class="rep" style="text-anchor: middle;"></text></g><g class="tick" transform="translate(224,0)" style="opacity: 1;"><line y2="-6" x2="0"></line><text y="-9" x="0" dy="0em" class="dem" style="text-anchor: middle;">+10</text></g><g class="tick" transform="translate(168,0)" style="opacity: 1;"><line y2="-6" x2="0"></line><text y="-9" x="0" dy="0em" class="dem" style="text-anchor: middle;">+20</text></g><g class="tick" transform="translate(112,0)" style="opacity: 1;"><line y2="-6" x2="0"></line><text y="-9" x="0" dy="0em" class="dem" style="text-anchor: middle;">+30</text></g><g class="tick" transform="translate(56,0)" style="opacity: 1;"><line y2="-6" x2="0"></line><text y="-9" x="0" dy="0em" class="dem" style="text-anchor: middle;">+40</text></g><g class="tick" transform="translate(0,0)" style="opacity: 1;"><line y2="-6" x2="0"></line><text y="-9" x="0" dy="0em" class="dem" style="text-anchor: middle;">+50</text></g><path class="domain" d="M0,-6V0H560V-6"></path></g><line class="grid" x1="560" x2="560" y1="0" y2="970"></line><line class="grid" x1="532" x2="532" y1="0" y2="970"></line><line class="grid" x1="504" x2="504" y1="0" y2="970"></line><line class="grid" x1="476" x2="476" y1="0" y2="970"></line><line class="grid" x1="448" x2="448" y1="0" y2="970"></line><line class="grid" x1="420" x2="420" y1="0" y2="970"></line><line class="grid" x1="392.00000000000006" x2="392.00000000000006" y1="0" y2="970"></line><line class="grid" x1="364" x2="364" y1="0" y2="970"></line><line class="grid" x1="336" x2="336" y1="0" y2="970"></line><line class="grid" x1="308" x2="308" y1="0" y2="970"></line><line class="grid zero" x1="280" x2="280" y1="-20" y2="970"></line><line class="grid" x1="252" x2="252" y1="0" y2="970"></line><line class="grid" x1="224" x2="224" y1="0" y2="970"></line><line class="grid" x1="196.00000000000003" x2="196.00000000000003" y1="0" y2="970"></line><line class="grid" x1="168" x2="168" y1="0" y2="970"></line><line class="grid" x1="140" x2="140" y1="0" y2="970"></line><line class="grid" x1="112" x2="112" y1="0" y2="970"></line><line class="grid" x1="84" x2="84" y1="0" y2="970"></line><line class="grid" x1="56" x2="56" y1="0" y2="970"></line><line class="grid" x1="28" x2="28" y1="0" y2="970"></line><line class="grid" x1="0" x2="0" y1="0" y2="970"></line></g><line x1="-190" x2="750" y1="17.142857142857142" y2="17.142857142857142" class="row-separator top"></line><g class="horiz-lines" transform="translate(0,21)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,47)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,73)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,99)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,125)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,151)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,177)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,203)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,229)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,255)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,281)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,307)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,333)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,359)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,385)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,411)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,437)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,463)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,489)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,515)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,541)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,567)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,593)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,619)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,645)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,671)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,697)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,723)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,749)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,775)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,801)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,827)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,853)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,879)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,905)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="horiz-lines" transform="translate(0,931)"><line x1="-190" x2="750" y1="21.857142857142858" y2="21.857142857142858" class="row-separator"></line></g><g class="state" transform="translate(0,21)"><rect class="bar" x="241.52446639999997" width="84.15584240000001" height="18"></rect><circle cx="283.54595024" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Colorado</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+1</text><text class="win-proj Colorado" dx="740" dy="15">55%</text></g><g class="state" transform="translate(0,47)"><rect class="bar" x="236.1704184" width="102.39169360000008" height="18"></rect><circle cx="287.0140112" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Iowa</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+1</text><text class="win-proj Iowa" dx="740" dy="15">59%</text></g><g class="state" transform="translate(0,73)"><rect class="bar" x="163.63972800000002" width="193.05708799999994" height="18"></rect><circle cx="260.2145952" cy="9" r="5" style="fill: rgb(119, 171, 67);"></circle><text class="state-name" x="-185" dy="15">Kansas</text><text class="favored" x="600" dy="15" style="fill: rgb(119, 171, 67);">I+4</text><text class="win-proj Kansas" dx="740" dy="15">63%</text></g><g class="state" transform="translate(0,99)"><rect class="bar" x="242.5949512" width="109.14071279999999" height="18"></rect><circle cx="297.0525432" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Alaska</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+3</text><text class="win-proj Alaska" dx="740" dy="15">70%</text></g><g class="state" transform="translate(0,125)"><rect class="bar" x="234.3142704" width="134.01637760000006" height="18"></rect><circle cx="301.67551679999997" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Louisiana</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+4</text><text class="win-proj Louisiana" dx="740" dy="15">70%</text></g><g class="state" transform="translate(0,151)"><rect class="bar" x="249.90850640000002" width="90.01121360000002" height="18"></rect><circle cx="295.0589488" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Georgia</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+3</text><text class="win-proj Georgia" dx="740" dy="15">71%</text></g><g class="state" transform="translate(0,177)"><rect class="bar" x="248.1776864" width="97.81730559999997" height="18"></rect><circle cx="296.995272" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Arkansas</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+3</text><text class="win-proj Arkansas" dx="740" dy="15">72%</text></g><g class="state" transform="translate(0,203)"><rect class="bar" x="221.466784" width="78.87711440000001" height="18"></rect><circle cx="260.9392296" cy="9" r="5" style="fill: rgb(0, 143, 213);"></circle><text class="state-name" x="-185" dy="15">New Hampshire</text><text class="favored" x="600" dy="15" style="fill: rgb(0, 143, 213);">D+3</text><text class="win-proj New Hampshire" dx="740" dy="15">79%</text></g><g class="state" transform="translate(0,229)"><rect class="bar" x="210.913024" width="92.09110400000003" height="18"></rect><circle cx="257.0091832" cy="9" r="5" style="fill: rgb(0, 143, 213);"></circle><text class="state-name" x="-185" dy="15">North Carolina</text><text class="favored" x="600" dy="15" style="fill: rgb(0, 143, 213);">D+4</text><text class="win-proj North Carolina" dx="740" dy="15">80%</text></g><g class="state" transform="translate(0,255)"><rect class="bar" x="263.73422880000004" width="97.12349919999997" height="18"></rect><circle cx="312.08671760000004" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Kentucky</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+6</text><text class="win-proj Kentucky" dx="740" dy="15">86%</text></g><g class="state" transform="translate(0,281)"><rect class="bar" x="198.28082400000002" width="95.18211920000002" height="18"></rect><circle cx="245.7880992" cy="9" r="5" style="fill: rgb(0, 143, 213);"></circle><text class="state-name" x="-185" dy="15">Michigan</text><text class="favored" x="600" dy="15" style="fill: rgb(0, 143, 213);">D+6</text><text class="win-proj Michigan" dx="740" dy="15">88%</text></g><g class="state" transform="translate(0,307)"><rect class="bar" x="168.244608" width="129.2624984" height="18"></rect><circle cx="232.7340848" cy="9" r="5" style="fill: rgb(0, 143, 213);"></circle><text class="state-name" x="-185" dy="15">Minnesota</text><text class="favored" x="600" dy="15" style="fill: rgb(0, 143, 213);">D+8</text><text class="win-proj Minnesota" dx="740" dy="15">89%</text></g><g class="state" transform="translate(0,333)"><rect class="bar" x="298.15666719999996" width="132.41876480000002" height="18"></rect><circle cx="364.631848" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">South Dakota</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+15</text><text class="win-proj South Dakota" dx="740" dy="15">95%</text></g><g class="state" transform="translate(0,359)"><rect class="bar" x="285.93924239999996" width="137.78296560000007" height="18"></rect><circle cx="355.167232" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">West Virginia</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+13</text><text class="win-proj West Virginia" dx="740" dy="15">96%</text></g><g class="state" transform="translate(0,385)"><rect class="bar" x="142.88876000000002" width="126.20165599999999" height="18"></rect><circle cx="206.114328" cy="9" r="5" style="fill: rgb(0, 143, 213);"></circle><text class="state-name" x="-185" dy="15">New Jersey</text><text class="favored" x="600" dy="15" style="fill: rgb(0, 143, 213);">D+13</text><text class="win-proj New Jersey" dx="740" dy="15">97%</text></g><g class="state" transform="translate(0,411)"><rect class="bar" x="125.176072" width="141.9415536" height="18"></rect><circle cx="196.18564" cy="9" r="5" style="fill: rgb(0, 143, 213);"></circle><text class="state-name" x="-185" dy="15">Oregon</text><text class="favored" x="600" dy="15" style="fill: rgb(0, 143, 213);">D+15</text><text class="win-proj Oregon" dx="740" dy="15">97%</text></g><g class="state" transform="translate(0,437)"><rect class="bar" x="151.529168" width="116.19254079999999" height="18"></rect><circle cx="209.350624" cy="9" r="5" style="fill: rgb(0, 143, 213);"></circle><text class="state-name" x="-185" dy="15">Virginia</text><text class="favored" x="600" dy="15" style="fill: rgb(0, 143, 213);">D+13</text><text class="win-proj Virginia" dx="740" dy="15">98%</text></g><g class="state" transform="translate(0,463)"><rect class="bar" x="298.4911216" width="148.7346784" height="18"></rect><circle cx="372.757336" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Mississippi</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+17</text><text class="win-proj Mississippi" dx="740" dy="15">98%</text></g><g class="state" transform="translate(0,489)"><rect class="bar" x="145.501552" width="119.39945360000002" height="18"></rect><circle cx="205.40923199999997" cy="9" r="5" style="fill: rgb(0, 143, 213);"></circle><text class="state-name" x="-185" dy="15">Illinois</text><text class="favored" x="600" dy="15" style="fill: rgb(0, 143, 213);">D+13</text><text class="win-proj Illinois" dx="740" dy="15">98%</text></g><g class="state" transform="translate(0,515)"><rect class="bar" x="95.14024800000001" width="160.9432608" height="18"></rect><circle cx="175.56789600000002" cy="9" r="5" style="fill: rgb(0, 143, 213);"></circle><text class="state-name" x="-185" dy="15">Delaware</text><text class="favored" x="600" dy="15" style="fill: rgb(0, 143, 213);">D+19</text><text class="win-proj Delaware" dx="740" dy="15">98%</text></g><g class="state" transform="translate(0,541)"><rect class="bar" x="300.13561760000005" width="136.07783840000002" height="18"></rect><circle cx="368.35030399999994" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Montana</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+16</text><text class="win-proj Montana" dx="740" dy="15">98%</text></g><g class="state" transform="translate(0,567)"><rect class="bar" x="310.7625864" width="171.85403760000003" height="18"></rect><circle cx="396.67689600000006" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Tennessee</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+21</text><text class="win-proj Tennessee" dx="740" dy="15">98%</text></g><g class="state" transform="translate(0,593)"><rect class="bar" x="306.3256" width="141.08970400000004" height="18"></rect><circle cx="376.67672000000005" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">South Carolina</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+17</text><text class="win-proj South Carolina" dx="740" dy="15">98%</text></g><g class="state" transform="translate(0,619)"><rect class="bar" x="322.1230992" width="157.34313279999998" height="18"></rect><circle cx="400.351784" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Nebraska</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+21</text><text class="win-proj Nebraska" dx="740" dy="15">&gt;99%</text></g><g class="state" transform="translate(0,645)"><rect class="bar" x="331.47927680000004" width="185.50185919999996" height="18"></rect><circle cx="424.0637520000001" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Maine</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+26</text><text class="win-proj Maine" dx="740" dy="15">&gt;99%</text></g><g class="state" transform="translate(0,671)"><rect class="bar" x="320.5009976" width="135.34314640000002" height="18"></rect><circle cx="388.12015199999996" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">South Carolina ★</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+19</text><text class="win-proj South Carolina" dx="740" dy="15">&gt;99%</text></g><g class="state" transform="translate(0,697)"><rect class="bar" x="24.31654399999998" width="196.05129599999998" height="18"></rect><circle cx="122.00775999999999" cy="9" r="5" style="fill: rgb(0, 143, 213);"></circle><text class="state-name" x="-185" dy="15">Rhode Island</text><text class="favored" x="600" dy="15" style="fill: rgb(0, 143, 213);">D+28</text><text class="win-proj Rhode Island" dx="740" dy="15">&gt;99%</text></g><g class="state" transform="translate(0,723)"><rect class="bar" x="323.65569600000003" width="137.33070400000003" height="18"></rect><circle cx="392.587776" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Texas</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+20</text><text class="win-proj Texas" dx="740" dy="15">&gt;99%</text></g><g class="state" transform="translate(0,749)"><rect class="bar" x="137.17625600000002" width="108.05784639999999" height="18"></rect><circle cx="191.09255200000004" cy="9" r="5" style="fill: rgb(0, 143, 213);"></circle><text class="state-name" x="-185" dy="15">New Mexico</text><text class="favored" x="600" dy="15" style="fill: rgb(0, 143, 213);">D+16</text><text class="win-proj New Mexico" dx="740" dy="15">&gt;99%</text></g><g class="state" transform="translate(0,775)"><rect class="bar" x="376.19288000000006" width="162.2082559999999" height="18"></rect><circle cx="457.07821600000005" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Idaho</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+32</text><text class="win-proj Idaho" dx="740" dy="15">&gt;99%</text></g><g class="state" transform="translate(0,801)"><rect class="bar" x="94.14529600000002" width="116.548096" height="18"></rect><circle cx="152.488168" cy="9" r="5" style="fill: rgb(0, 143, 213);"></circle><text class="state-name" x="-185" dy="15">Massachusetts</text><text class="favored" x="600" dy="15" style="fill: rgb(0, 143, 213);">D+23</text><text class="win-proj Massachusetts" dx="740" dy="15">&gt;99%</text></g><g class="state" transform="translate(0,827)"><rect class="bar" x="371.21688800000004" width="150.1666879999999" height="18"></rect><circle cx="446.324928" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Oklahoma</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+30</text><text class="win-proj Oklahoma" dx="740" dy="15">&gt;99%</text></g><g class="state" transform="translate(0,853)"><rect class="bar" x="370.232632" width="143.654336" height="18"></rect><circle cx="441.574224" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Oklahoma ★</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+29</text><text class="win-proj Oklahoma" dx="740" dy="15">&gt;99%</text></g><g class="state" transform="translate(0,879)"><rect class="bar" x="17.692919999999997" width="145.02583200000004" height="18"></rect><circle cx="90.20524800000001" cy="9" r="5" style="fill: rgb(0, 143, 213);"></circle><text class="state-name" x="-185" dy="15">Hawaii ★</text><text class="favored" x="600" dy="15" style="fill: rgb(0, 143, 213);">D+34</text><text class="win-proj Hawaii" dx="740" dy="15">&gt;99%</text></g><g class="state" transform="translate(0,905)"><rect class="bar" x="430.61586400000004" width="167.23739200000006" height="18"></rect><circle cx="513.976456" cy="9" r="5" style="fill: rgb(255, 39, 0);"></circle><text class="state-name" x="-185" dy="15">Wyoming</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+42</text><text class="win-proj Wyoming" dx="740" dy="15">&gt;99%</text></g><g class="uncontested" transform="translate(0,931)"><rect class="bar" x="840" width="0" height="18"></rect><circle cx="840" cy="9" r="0" style="fill: rgb(255, 39, 0);"></circle><rect x="460" width="110" height="18"></rect><text x="570" y="13" class="label" text-anchor="end">uncontested</text><text class="state-name" x="-185" dy="15">Alabama</text><text class="favored" x="600" dy="15" style="fill: rgb(255, 39, 0);">R+100</text><text class="win-proj Alabama" dx="740" dy="15">100%</text></g><g class="key" transform="translate(0,134)" opacity="1"><line x1="296.67551679999997" x2="169.3142704"></line><rect x="69.3142704" width="96" height="47.5" y="-14.5"></rect><text x="161.3142704" y="5" class="end strong">Most likely</text><text x="161.3142704" y="24" class="end">outcome</text><line x1="368.33064800000005" x2="433.33064800000005"></line><rect x="437.33064800000005" width="110" height="66.5" y="-14.5"></rect><text x="441.33064800000005" y="5" class="strong">90% chance</text><text x="441.33064800000005" y="24">of falling in</text><text x="441.33064800000005" y="43">this range</text></g></g>"""

# %%
len(elements) #This was from October 5 at 4pm
# Out:
# 25817

# %%
import re

# %%
widths=re.findall('width="(\d+\.\d+)"',elements)
centers=re.findall('cx="(\d+\.\d+)"',elements)
states=re.findall('class="state-name"[^>]*>([^<]+)</text>',elements)[:35]

# %%
len(widths), len(centers), len(states)
# Out:
# (35, 35, 35)

# %%
data={} #data from Oct 5 at 5:00pm
for state,center,width in zip(states,centers,widths):
    data[state]=(float(center)/560, float(width)/(560*2*1.645))

# %%
def rvote():
    counter = 0
    for value in data.values():
        x = value[0]
        y = value[1]
        if normal(x,y) > 0.5:
            counter = counter + 1
    return 31 + counter

# %%
rvote()
# Out:
# 50

# %%
N=1000 #for testing, just use 1000
figure(figsize=(8,6))
n,b,p=hist([rvote() for t in xrange(N)],bins=range(34,70),align='left',normed=True)
xlim(42,60)
xlabel('Republican Seats')
xticks(range(42,61));

# %%
import matplotlib.patches as patches
figure(figsize=(8,6))
nytred = (186/255., 58/255., 50/255.)
nytblue = (68/255., 94/255., 150/255.)

for i in arange(0,35):
    if b[i] >= 50.5:
        bar(b[i],n[i],color=nytred,align='center')
    else:
        bar(b[i],n[i],color=nytblue,align='center')
title('Who controls? (using data from 5 Oct 2014)')
xlabel('Republican Seats')
ylabel('Probability')
legend(handles=[patches.Patch(color = nytred, label = 'Republican'),patches.Patch(color = nytblue, label = 'Democrat')])

# %%
del states[2]##Removes the Kansas element from the list of states
def newrvote():
    counter = 0
    for value in data.values():
        x = value[0]
        y = value[1]
        if normal(x,y) > 0.5:
            counter = counter + 1
    return 31 + counter
    if counter >= 51:
        counter = counter + 1
    else:
        if data[Kansas][0] > .5:
            counter = counter + 1

# %%
N=1000 #for testing, just use 1000
figure(figsize=(8,6))
o,c,q=hist([newrvote() for t in xrange(N)],bins=range(34,70),align='left',normed=True)
xlim(42,60)
xlabel('Republican Seats')
xticks(range(42,61));

# %%
import matplotlib.patches as patches
figure(figsize=(8,6))
nytred = (186/255., 58/255., 50/255.)
nytblue = (68/255., 94/255., 150/255.)

for i in arange(0,35):
    if c[i] >= 50.5:
        bar(c[i],o[i],color=nytred,align='center')
    else:
        bar(c[i],o[i],color=nytblue,align='center')
title('Who controls? (using data from 5 Oct 2014)')
xlabel('Republican Seats')
ylabel('Probability')
legend(handles=[patches.Patch(color = nytred, label = 'Republican'),patches.Patch(color = nytblue, label = 'Democrat')])

# %%
prediction = {'Colorado': 0.3738404, 'Iowa': 0.7970088, 'Kansas': 0.313514, 'Alaska': 0.41559658, 'Louisiana': 0.36680219999999997, 'Georgia': 0.5303487, 'Arkansas': 0.34123670000000006, 'New Hampshire': 0.53870628, 'North Carolina': 0.7010496, 'Kentucky': 0.9178151, 'Michigan': 0.51252502, 'Minnesota': 0.43890732, 'South Dakota': 0.46466892000000004, 'West Virginia': 0.3738404, 'New Jersey': 0.3503315, 'Oregon': 0.6577683999999999, 'Virginia': 0.46596290999999995, 'Mississippi': 0.8162111000000001, 'Illinois': 0.6342272, 'Delaware': 0.672637, 'Montana': 0.2723003, 'Tennessee': 0.52689098, 'South Carolina': 0.53045097, 'Nebraska': 0.5572977100000001, 'Maine': 0.21787099999999998, 'South Carolina': 0.6930717, 'Rhode Island': 0.7149139, 'Texas': 0.6511283, 'New Mexico': 0.506332054, 'Idaho': 0.3680613, 'Massachusetts': 0.45894497, 'Oklahoma': 0.7885254, 'Oklahoma': 0.7083516000000001, 'Hawaii': 0.7572567000000001, 'Wyoming': 0.16108080000000002}
from mpl_toolkits.basemap import Basemap
myblue=array([.1,.1,.7])
nytred=array([186,58,50])/255.
nytbeige = array([245, 222, 150])/255.

def mycolor(p):
    bias=abs(p-.5)
    if bias <=.03+1e-10: return nytbeige #.47 <= p <= .53
    color = myblue if p > .5 else nytred
    if bias < 1./6.: color = 6.*bias*color + (1.-6.*bias)*ones(3)
    return color  #linear interpolation for 1/3 < p < 2/3
    
figure(figsize=(12,6))
m = Basemap(llcrnrlon=-119,llcrnrlat=22,urcrnrlon=-64,urcrnrlat=49,
             projection='lcc',lat_1=33,lat_2=45,lon_0=-95)
m.readshapefile('geodata/st99_d90','states',drawbounds=True,color='w')

for seg,info in zip(m.states,m.states_info):
  state=info['NAME']
  if state in ('Alaska','Hawaii'): continue  #only lower 48
  xx,yy = zip(*seg)
  if state in prediction: # only if election in '14
     color = mycolor(prediction[state])
     fill(xx,yy,color=color,edgecolor=color)
  else:  #light gray
     fill(xx,yy,'.95',edgecolor='.95') 
                
for seg,info in zip(m.states,m.states_info):
  state=info['NAME']
#  if state != 'Alaska' and state != 'Hawaii': continue
  xx,yy = zip(*seg)
  if state in prediction: color = mycolor(prediction[state])
  else: color='gray'
  fill(xx,yy,color=color,edgecolor=color)
            
#http://matplotlib.org/examples/pylab_examples/axes_demo.html
figure(figsize=(12,6))

#first the lower 48, already read into Basemap() two cells above

for seg,info in zip(m.states,m.states_info):
  state=info['NAME']
  if state in ('Alaska','Hawaii'): continue  #only lower 48
  xx,yy = zip(*seg)
  if state in prediction: # only if election in '14
     color = mycolor(prediction[state])
     fill(xx,yy,color=color,edgecolor=color)
  else:  #light gray
     fill(xx,yy,'.95',edgecolor='.95') 

#now Alaska
axes([.196,.125,.18,.18]) #coords of lower left corner, width, height
m = Basemap(llcrnrlon=-180,llcrnrlat=50,urcrnrlon=-115,urcrnrlat=67,
   projection='lcc',lat_1=60,lat_2=65,lon_0=-155)
m.readshapefile('geodata/st99_d90','states',drawbounds=True,color='w')
axis('off')  #turn off surrounding black box
for seg,info in zip(m.states,m.states_info):
  state=info['NAME']
  if state != 'Alaska': continue
  xx,yy = zip(*seg)
  color = mycolor(prediction[state])
  fill(xx,yy,color=color,edgecolor=color)

#and Hawaii
axes([.35,.15,.08,.08]) #coords of lower left corner, width, height
m = Basemap(llcrnrlon=-161,llcrnrlat=18,urcrnrlon=-154,urcrnrlat=23,
  projection='lcc',lat_1=19,lat_2=22,lon_0=-157)
m.readshapefile('geodata/st99_d90','states',drawbounds=True,color=myblue)
axis('off')  #turn off surrounding black box
for seg,info in zip(m.states,m.states_info):
  state=info['NAME']
  if state != 'Hawaii': continue
  xx,yy = zip(*seg)
  color = mycolor(prediction[state])
  fill(xx,yy,color=color,edgecolor=color)
